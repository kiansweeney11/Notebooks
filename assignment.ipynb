# %%
import pandas as pd

# %%
# reading in the files to compare and contrast their respective layouts, columns etc.

# %%
rsa_zerofive = pd.read_csv("rsa_2005-2006-Copy1.csv")

# %%
rsa_zerofive.head()
# Out:
#    Unnamed: 0          Age   Sex     Participant CasualtyType 2005  2006
# 0           0  0 - 5 years  Male     Pedestrians      Injured   36    32
# 1           1  0 - 5 years  Male     Pedestrians       Killed    3     1
# 2           2  0 - 5 years  Male  Pedal cyclists      Injured    0     0
# 3           3  0 - 5 years  Male  Pedal cyclists       Killed    0     0
# 4           4  0 - 5 years  Male  Motor cyclists      Injured    0     0

# %%
rsa_zero_seven = pd.read_json('rsa_2007-2008-Copy1.json')

# %%
rsa_zero_seven.head()
# Out:
#                Age   Sex       Participant CasualtyType  2007 2008
# 0      0 - 5 years  Male       Pedestrians      Injured    28   54
# 1      0 - 5 years  Male       Pedestrians       Killed     0    1
# 10     0 - 5 years  Male  Other road users      Injured     2    3
# 100  18 - 20 years  Male    Motor cyclists      Injured    21   20
# 101  18 - 20 years  Male    Motor cyclists       Killed     3    2

# %%
rsa_eleven = pd.read_excel('rsa_2011-2012-Copy1.xlsx', index_col=0)
rsa_eleven.head()
# Out:
#        Sex     Participant CasualtyType  2011  2012
# Age
# 0 - 5    M     Pedestrians      Injured    39    40
# 0 - 5    M     Pedestrians       Killed     0     0
# 0 - 5    M  Pedal cyclists      Injured     3     1
# 0 - 5    M  Pedal cyclists       Killed     1     0
# 0 - 5    M  Motor cyclists      Injured     0     0

# %%
rsa_fifteen = pd.read_excel('rsa_2013-2015-Copy1.xlsx', index_col=0)
rsa_fifteen
# Out:
#             Unnamed: 1        Unnamed: 2                        2013  \
# NaN                NaN               NaN  Killed Casualties (Number)
# All ages          Male    All road users                         142
# NaN                NaN       Pedestrians                          18
# NaN                NaN    Pedal cyclists                           4
# NaN                NaN    Motor cyclists                          24
# NaN                NaN     All Car users                          81
# NaN                NaN       Car drivers                          61
# NaN                NaN    Car passengers                          20
# NaN                NaN  Other road users                          15
# NaN             Female    All road users                          46
# NaN                NaN       Pedestrians                          13
# NaN                NaN    Pedal cyclists                           1
# NaN                NaN    Motor cyclists                           2
# ...

# %%
rsa_fifteen.head()
# Out:
#          Unnamed: 1      Unnamed: 2                        2013  \
# NaN             NaN             NaN  Killed Casualties (Number)
# All ages       Male  All road users                         142
# NaN             NaN     Pedestrians                          18
# NaN             NaN  Pedal cyclists                           4
# NaN             NaN  Motor cyclists                          24
#
#                             Unnamed: 4  \
# NaN       Injured Cassualties (Number)
# All ages                          3816
# NaN                                499
# NaN                                468
# NaN                                244
#
#                                           Unnamed: 5  \
# NaN       All Killed and Injured Casualties (Number)
# All ages                                        3958
# NaN                                              517
# NaN                                              472
# NaN                                              268
#
# ...

# %%
rsa_fifteen.head(1)
# Out:
#     Unnamed: 1 Unnamed: 2                        2013  \
# NaN        NaN        NaN  Killed Casualties (Number)
#
#                        Unnamed: 4                                  Unnamed: 5  \
# NaN  Injured Cassualties (Number)  All Killed and Injured Casualties (Number)
#
#                            2014                    Unnamed: 7  \
# NaN  Killed Casualties (Number)  Injured Cassualties (Number)
#
#                                      Unnamed: 8                        2016  \
# NaN  All Killed and Injured Casualties (Number)  Killed Casualties (Number)
#
#                       Unnamed: 10                                 Unnamed: 11
# NaN  Injured Cassualties (Number)  All Killed and Injured Casualties (Number)

# %%
rsa_fifteen.head(0)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 1, Unnamed: 2, 2013, Unnamed: 4, Unnamed: 5, 2014, Unnamed: 7, Unnamed: 8, 2016, Unnamed: 10, Unnamed: 11]
# Index: []

# %%
rsa_fifteen.head(0)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 1, Unnamed: 2, 2013, Unnamed: 4, Unnamed: 5, 2014, Unnamed: 7, Unnamed: 8, 2016, Unnamed: 10, Unnamed: 11]
# Index: []

# %%
rsa_zerofive.head()
# Out:
#    Unnamed: 0          Age   Sex     Participant CasualtyType 2005  2006
# 0           0  0 - 5 years  Male     Pedestrians      Injured   36    32
# 1           1  0 - 5 years  Male     Pedestrians       Killed    3     1
# 2           2  0 - 5 years  Male  Pedal cyclists      Injured    0     0
# 3           3  0 - 5 years  Male  Pedal cyclists       Killed    0     0
# 4           4  0 - 5 years  Male  Motor cyclists      Injured    0     0

# %%
rsa_zerofive.loc[rsa_zerofive["Age"] == ""]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Age, Sex, Participant, CasualtyType, 2005, 2006]
# Index: []

# %%
rsa_zerofive.tail()
# Out:
#      Unnamed: 0          Age     Sex       Participant CasualtyType 2005  2006
# 283         283  Age unknown  Female       Car drivers       Killed    0     0
# 284         284  Age unknown  Female    Car passengers      Injured   32    38
# 285         285  Age unknown  Female    Car passengers       Killed    1     0
# 286         286  Age unknown  Female  Other road users      Injured   12    11
# 287         287  Age unknown  Female  Other road users       Killed    0     0

# %%
df1 = pd.DataFrame(rsa_zerofive, columns=["Age", "Sex", "Participant", "CasualtyType", "2005", "2006"])

# %%
df2 = pd.DataFrame(rsa_zero_seven)

# %%
df2.head()
# Out:
#                Age   Sex       Participant CasualtyType  2007 2008
# 0      0 - 5 years  Male       Pedestrians      Injured    28   54
# 1      0 - 5 years  Male       Pedestrians       Killed     0    1
# 10     0 - 5 years  Male  Other road users      Injured     2    3
# 100  18 - 20 years  Male    Motor cyclists      Injured    21   20
# 101  18 - 20 years  Male    Motor cyclists       Killed     3    2

# %%
df2.head()
# Out:
#                Age   Sex       Participant CasualtyType  2007 2008
# 0      0 - 5 years  Male       Pedestrians      Injured    28   54
# 1      0 - 5 years  Male       Pedestrians       Killed     0    1
# 10     0 - 5 years  Male  Other road users      Injured     2    3
# 100  18 - 20 years  Male    Motor cyclists      Injured    21   20
# 101  18 - 20 years  Male    Motor cyclists       Killed     3    2

# %%
df1
# Out:
#                    Age     Sex       Participant CasualtyType 2005  2006
# 0          0 - 5 years    Male       Pedestrians      Injured   36    32
# 1          0 - 5 years    Male       Pedestrians       Killed    3     1
# 2          0 - 5 years    Male    Pedal cyclists      Injured    0     0
# 3          0 - 5 years    Male    Pedal cyclists       Killed    0     0
# 4          0 - 5 years    Male    Motor cyclists      Injured    0     0
# 5          0 - 5 years    Male    Motor cyclists       Killed    0     0
# 6          0 - 5 years    Male       Car drivers      Injured    1     0
# 7          0 - 5 years    Male       Car drivers       Killed    0     0
# 8          0 - 5 years    Male    Car passengers      Injured   52    51
# 9          0 - 5 years    Male    Car passengers       Killed    0     4
# 10         0 - 5 years    Male  Other road users      Injured    4     6
# 11         0 - 5 years    Male  Other road users       Killed    0     0
# ...

# %%
DF = pd.merge(df1, df2)

# %%
df1
# Out:
#                    Age     Sex       Participant CasualtyType 2005  2006
# 0          0 - 5 years    Male       Pedestrians      Injured   36    32
# 1          0 - 5 years    Male       Pedestrians       Killed    3     1
# 2          0 - 5 years    Male    Pedal cyclists      Injured    0     0
# 3          0 - 5 years    Male    Pedal cyclists       Killed    0     0
# 4          0 - 5 years    Male    Motor cyclists      Injured    0     0
# 5          0 - 5 years    Male    Motor cyclists       Killed    0     0
# 6          0 - 5 years    Male       Car drivers      Injured    1     0
# 7          0 - 5 years    Male       Car drivers       Killed    0     0
# 8          0 - 5 years    Male    Car passengers      Injured   52    51
# 9          0 - 5 years    Male    Car passengers       Killed    0     4
# 10         0 - 5 years    Male  Other road users      Injured    4     6
# 11         0 - 5 years    Male  Other road users       Killed    0     0
# ...

# %%
df1.head()
# Out:
#            Age   Sex     Participant CasualtyType 2005  2006
# 0  0 - 5 years  Male     Pedestrians      Injured   36    32
# 1  0 - 5 years  Male     Pedestrians       Killed    3     1
# 2  0 - 5 years  Male  Pedal cyclists      Injured    0     0
# 3  0 - 5 years  Male  Pedal cyclists       Killed    0     0
# 4  0 - 5 years  Male  Motor cyclists      Injured    0     0

# %%
df = pd.merge(df1, df2)

# %%
df
# Out:
#                    Age     Sex       Participant CasualtyType 2005  2006  \
# 0          0 - 5 years    Male       Pedestrians      Injured   36    32
# 1          0 - 5 years    Male       Pedestrians       Killed    3     1
# 2          0 - 5 years    Male    Pedal cyclists      Injured    0     0
# 3          0 - 5 years    Male    Pedal cyclists       Killed    0     0
# 4          0 - 5 years    Male    Motor cyclists      Injured    0     0
# 5          0 - 5 years    Male    Motor cyclists       Killed    0     0
# 6          0 - 5 years    Male       Car drivers      Injured    1     0
# 7          0 - 5 years    Male       Car drivers       Killed    0     0
# 8          0 - 5 years    Male    Car passengers      Injured   52    51
# 9          0 - 5 years    Male    Car passengers       Killed    0     4
# 10         0 - 5 years    Male  Other road users      Injured    4     6
# 11         0 - 5 years    Male  Other road users       Killed    0     0
# ...

# %%
# to successfully merge I needed a consistent number of rows in my merges. 
# In this case this figure was 288 and as per above I did not have this value required.

# %%
df1.dtypes
# Out:
# Age             object
# Sex             object
# Participant     object
# CasualtyType    object
# 2005            object
# 2006             int64
# dtype: object

# %%
# I found inconsistent datatypes in the 2005 column and needed to make it consistent with the others to merge successfully with df2

# %%
df.dtypes
# Out:
# Age             object
# Sex             object
# Participant     object
# CasualtyType    object
# 2005            object
# 2006             int64
# 2007             int64
# 2008            object
# dtype: object

# %%
for i in df1['2005']:
    if i.isnumeric() != True:
        print(i)
# Out:
# 30  '
# 0'
# 5;
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-b3cdb63b3098> in <module>
#       1 for i in df1['2005']:
# ----> 2     if i.isnumeric() != True:
#       3         print(i)
#
# AttributeError: 'float' object has no attribute 'isnumeric'

# %%
j = 0  #linear search position of each invalid object
while j < len(df1['2005']) and df1['2005'][j] != "30  '":
    j += 1
print(j)
# Out:
# 132

# %%
df1.loc[132, '2005'] = 30

# %%
df1['2005'].fillna('0', inplace=True)

# %%
df1.loc[134, '2005'] = 5

# %%
df1.loc[133, '2005'] = 0

# %%
df1['2005'] = df1['2005'].astype('int64')
df1.dtypes
# Out:
# Age             object
# Sex             object
# Participant     object
# CasualtyType    object
# 2005             int64
# 2006             int64
# dtype: object

# %%
df2 = df2.sort_index()
df2.head()
# Out:
#            Age   Sex     Participant CasualtyType  2007 2008
# 0  0 - 5 years  Male     Pedestrians      Injured    28   54
# 1  0 - 5 years  Male     Pedestrians       Killed     0    1
# 2  0 - 5 years  Male  Pedal cyclists      Injured     2    0
# 3  0 - 5 years  Male  Pedal cyclists       Killed     0    0
# 4  0 - 5 years  Male  Motor cyclists      Injured     0    0

# %%
df2.dtypes
# Out:
# Age             object
# Sex             object
# Participant     object
# CasualtyType    object
# 2007             int64
# 2008            object
# dtype: object

# %%
for i in df2['2008']:
    if i.isnumeric() != True:
        print(i)
# Out:
# O

# %%
j = 0
while j < len(df2['2008']) and df2['2008'][j] != "O":
    j += 1
print(j)
# Out:
# 287

# %%
df2.loc[287, '2008'] = 0

# %%
df2['2008'] = df2['2008'].astype('int64')
df2.dtypes
# Out:
# Age             object
# Sex             object
# Participant     object
# CasualtyType    object
# 2007             int64
# 2008             int64
# dtype: object

# %%
DF = pd.merge(left=df1, right=df2)

# %%
df2["Sex"].value_counts()
# Out:
# Male      144
# Female    142
# fmeale      2
# Name: Sex, dtype: int64

# %%
df2["Participant"].value_counts()
# Out:
# Pedal cyclists      48
# Car passengers      48
# Other road users    48
# Car drivers         48
# Motor cyclists      48
# Pedestrians         46
# Pedestrains          2
# Name: Participant, dtype: int64

# %%
df2.Sex[df2.Sex == 'fmeale'] = 'Female'
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['Sex'].value_counts()
# Out:
# Male      144
# Female    144
# Name: Sex, dtype: int64

# %%
df2.Participant[df2.Participant == 'Pedestrains'] = 'Pedestrians'
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['Participant'].value_counts()
# Out:
# Pedal cyclists      48
# Pedestrians         48
# Car passengers      48
# Other road users    48
# Car drivers         48
# Motor cyclists      48
# Name: Participant, dtype: int64

# %%
DF = pd.merge(left=df1, right=df2)

# %%
DF.shape
# Out:
# (288, 8)

# %%
df3 = pd.read_csv('rsa_2009-2010-Copy1.txt', header=None, delimiter='\t', names=['Age', 'Sex', 'Participant', 'CasualtyType', '2009', '2010'])

# %%
df3.head()
# Out:
#            Age   Sex     Participant CasualtyType  2009  2010
# 0  0 - 5 years  Male     Pedestrians      Injured    35    41
# 1  0 - 5 years  Male     Pedestrians       Killed     3     3
# 2  0 - 5 years  Male  Pedal cyclists      Injured     2     5
# 3  0 - 5 years  Male  Pedal cyclists       Killed     0     0
# 4  0 - 5 years  Male  Motor cyclists      Injured     0     0

# %%
df3.shape
# Out:
# (288, 6)

# %%
df3.dtypes
# Out:
# Age             object
# Sex             object
# Participant     object
# CasualtyType    object
# 2009             int64
# 2010             int64
# dtype: object

# %%
df123 = pd.merge(left=DF, right=df3)

# %%
df123.shape
# Out:
# (288, 10)

# %%
df4 = pd.read_excel('rsa_2011-2012-Copy1.xlsx')

# %%
df4.shape
# Out:
# (288, 6)

# %%
df4.tail()
# Out:
#              Age Sex       Participant CasualtyType  2011  2012
# 283  Age unknown   F       Car drivers       Killed     0     0
# 284  Age unknown   F    Car passengers      Injured    10    11
# 285  Age unknown   F    Car passengers       Killed     0     0
# 286  Age unknown   F  Other road users      Injured     0     0
# 287  Age unknown   F  Other road users       Killed     0     0

# %%
df4.Sex[df4.Sex == 'M'] = 'Male'
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df4.Sex[df4.Sex == 'F'] = 'Female'
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df4['Sex'].value_counts()
# Out:
# Male      144
# Female    144
# Name: Sex, dtype: int64

# %%
df4.dtypes
# Out:
# Age             object
# Sex             object
# Participant     object
# CasualtyType    object
# 2011             int64
# 2012             int64
# dtype: object

# %%
df4['Participant'].value_counts()
# Out:
# Pedal cyclists      48
# Pedestrians         48
# Car passengers      48
# Other road users    48
# Car drivers         48
# Motor cyclists      48
# Name: Participant, dtype: int64

# %%
df4['Age'].value_counts()
# Out:
# 18 - 20                24
# 25 - 34                24
# 21 - 24                24
# 65  and over           24
# 55 - 64                24
# 35 - 44                24
# 15 - 17                24
# 45 - 54                24
# 2019-09-06 00:00:00    24
# 0 - 5                  24
# 2014-10-01 00:00:00    24
# Age unknown            24
# Name: Age, dtype: int64

# %%
df123['Age'].value_counts()
# Out:
# 10 - 14 years        24
# 55 - 64 years        24
# 18 - 20 years        24
# 35 - 44 years        24
# 25 - 34 years        24
# 15 - 17 years        24
# 6 - 9 years          24
# 45 - 54 years        24
# 0 - 5 years          24
# 65 years and over    24
# Age unknown          24
# 21 - 24 years        24
# Name: Age, dtype: int64

# %%
df4.head()
# Out:
#       Age   Sex     Participant CasualtyType  2011  2012
# 0  0 - 5   Male     Pedestrians      Injured    39    40
# 1  0 - 5   Male     Pedestrians       Killed     0     0
# 2  0 - 5   Male  Pedal cyclists      Injured     3     1
# 3  0 - 5   Male  Pedal cyclists       Killed     1     0
# 4  0 - 5   Male  Motor cyclists      Injured     0     0

# %%
df4['Age'].value_counts()
# Out:
# 18 - 20                24
# 25 - 34                24
# 21 - 24                24
# 65  and over           24
# 55 - 64                24
# 35 - 44                24
# 15 - 17                24
# 45 - 54                24
# 2019-09-06 00:00:00    24
# 0 - 5                  24
# 2014-10-01 00:00:00    24
# Age unknown            24
# Name: Age, dtype: int64

# %%
i = 0
while i < 24:
    df4.at[i, 'Age'] = '0 - 5 years'
    i += 1

# %%
df4['Age'].value_counts()
# Out:
# 18 - 20                24
# 25 - 34                24
# 21 - 24                24
# 65  and over           24
# 55 - 64                24
# 35 - 44                24
# 15 - 17                24
# 45 - 54                24
# 2019-09-06 00:00:00    24
# 2014-10-01 00:00:00    24
# 0 - 5 years            24
# Age unknown            24
# Name: Age, dtype: int64

# %%
#I figured out by testing I couldn't use previous methods to change values in a column 
#This led to me to using the 'at' method

# %%
i = 24    # index is sorted so ages ascending, hence adding 24 to loops each time
while i < 48:
    df4.at[i, 'Age'] = '6 - 9 years'
    i += 1

# %%
df4['Age'].value_counts()
# Out:
# 18 - 20                24
# 25 - 34                24
# 21 - 24                24
# 65  and over           24
# 55 - 64                24
# 35 - 44                24
# 15 - 17                24
# 45 - 54                24
# 6 - 9 years            24
# 2014-10-01 00:00:00    24
# 0 - 5 years            24
# Age unknown            24
# Name: Age, dtype: int64

# %%
df4.head(50)
# Out:
#                     Age     Sex       Participant CasualtyType  2011  2012
# 0           0 - 5 years    Male       Pedestrians      Injured    39    40
# 1           0 - 5 years    Male       Pedestrians       Killed     0     0
# 2           0 - 5 years    Male    Pedal cyclists      Injured     3     1
# 3           0 - 5 years    Male    Pedal cyclists       Killed     1     0
# 4           0 - 5 years    Male    Motor cyclists      Injured     0     0
# 5           0 - 5 years    Male    Motor cyclists       Killed     0     0
# 6           0 - 5 years    Male       Car drivers      Injured     0     0
# 7           0 - 5 years    Male       Car drivers       Killed     0     0
# 8           0 - 5 years    Male    Car passengers      Injured    54    83
# 9           0 - 5 years    Male    Car passengers       Killed     1     0
# 10          0 - 5 years    Male  Other road users      Injured     2     2
# ...

# %%
i = 48
while i < 72:
    df4.at[i, 'Age'] = '10 - 14 years'
    i += 1

# %%
df4['Age'].value_counts()
# Out:
# 18 - 20          24
# 25 - 34          24
# 10 - 14 years    24
# 21 - 24          24
# 65  and over     24
# 55 - 64          24
# 35 - 44          24
# 15 - 17          24
# 45 - 54          24
# 6 - 9 years      24
# 0 - 5 years      24
# Age unknown      24
# Name: Age, dtype: int64

# %%
i = 72
while i < 96:
    df4.at[i, 'Age'] = '15 - 17 years'
    i += 1

# %%
i = 96
while i < 120:
    df4.at[i, 'Age'] = '18 - 20 years'
    i += 1

# %%
df4['Age'].value_counts()
# Out:
# 25 - 34          24
# 10 - 14 years    24
# 21 - 24          24
# 65  and over     24
# 55 - 64          24
# 18 - 20 years    24
# 35 - 44          24
# 45 - 54          24
# 15 - 17 years    24
# 6 - 9 years      24
# 0 - 5 years      24
# Age unknown      24
# Name: Age, dtype: int64

# %%
i = 120
while i < 144:
    df4.at[i, 'Age'] = '21 - 24 years'
    i += 1

# %%
i = 144
while i < 168:
    df4.at[i, 'Age'] = '25 - 34 years'
    i += 1

# %%
i = 168
while i < 192:
    df4.at[i, 'Age'] = '35 - 44 years'
    i += 1

# %%
i = 192
while i < 216:
    df4.at[i, 'Age'] = '45 - 54 years'
    i += 1

# %%
i = 216
while i < 240:
    df4.at[i, 'Age'] = '55 - 64 years'
    i += 1

# %%
df4['Age'].value_counts()
# Out:
# 10 - 14 years    24
# 55 - 64 years    24
# 65  and over     24
# 18 - 20 years    24
# 35 - 44 years    24
# 25 - 34 years    24
# 15 - 17 years    24
# 6 - 9 years      24
# 45 - 54 years    24
# 0 - 5 years      24
# Age unknown      24
# 21 - 24 years    24
# Name: Age, dtype: int64

# %%
df4.shape
# Out:
# (288, 6)

# %%
i = 240
while i < 264:
    df4.at[i, 'Age'] = '65 years and over'
    i += 1

# %%
df1234 = pd.merge(left=df123, right=df4)

# %%
df1234.shape
# Out:
# (288, 12)

# %%
df1234.head()
# Out:
#            Age   Sex     Participant CasualtyType  2005  2006  2007  2008  \
# 0  0 - 5 years  Male     Pedestrians      Injured    36    32    28    54
# 1  0 - 5 years  Male     Pedestrians       Killed     3     1     0     1
# 2  0 - 5 years  Male  Pedal cyclists      Injured     0     0     2     0
# 3  0 - 5 years  Male  Pedal cyclists       Killed     0     0     0     0
# 4  0 - 5 years  Male  Motor cyclists      Injured     0     0     0     0
#
#    2009  2010  2011  2012
# 0    35    41    39    40
# 1     3     3     0     0
# 2     2     5     3     1
# 3     0     0     1     0
# 4     0     0     0     0

# %%
# i tried reading in the file as normal but encountered many issues with doing so
# this made me use the parameters of index_col to make the file more manageable
# this was because it was an multi index dataframe

# %%
df5 = pd.read_excel('rsa_2013-2015-Copy1.xlsx', index_col=[0,1])

# %%
df5.reset_index(inplace=True)

# %%
df5.head(20)
# Out:
#         level_0 level_1        Unnamed: 2                        2013  \
# 0           NaN     NaN               NaN  Killed Casualties (Number)
# 1      All ages    Male    All road users                         142
# 2      All ages    Male       Pedestrians                          18
# 3      All ages    Male    Pedal cyclists                           4
# 4      All ages    Male    Motor cyclists                          24
# 5      All ages    Male     All Car users                          81
# 6      All ages    Male       Car drivers                          61
# 7      All ages    Male    Car passengers                          20
# 8      All ages    Male  Other road users                          15
# 9      All ages  Female    All road users                          46
# 10     All ages  Female       Pedestrians                          13
# 11     All ages  Female    Pedal cyclists                           1
# ...

# %%
df5 = df5[df5.level_0 != 'All ages']

# %%
df5 = df5.iloc[1:]

# %%
# all ages is not in age columns of other dataframe and must be be removed to help merge
# first row must also be removed as it has no correlation to other rows in other dataframes

# %%
df5.head()
# Out:
#         level_0 level_1      Unnamed: 2 2013 Unnamed: 4 Unnamed: 5 2014  \
# 17  0 - 5 years    Male  All road users    1         88         89    3
# 18  0 - 5 years    Male     Pedestrians    0         29         29    0
# 19  0 - 5 years    Male  Pedal cyclists    0          1          1    0
# 20  0 - 5 years    Male  Motor cyclists    0          0          0    0
# 21  0 - 5 years    Male   All Car users    1         53         54    3
#
#    Unnamed: 7 Unnamed: 8 2016 Unnamed: 10 Unnamed: 11
# 17        121        124    1          97          98
# 18         47         47    0          28          28
# 19          1          1    0           3           3
# 20          0          0    0           0           0
# 21         70         73    1          63          64

# %%
df5.shape
# Out:
# (194, 12)

# %%
df5 = df5.rename(columns={'level_0':'Age', 'level_1':'Sex', 'Unnamed: 2':'Participant', 2016: 2015})

# %%
df5.head()
# Out:
#             Age   Sex     Participant 2013 Unnamed: 4 Unnamed: 5 2014  \
# 17  0 - 5 years  Male  All road users    1         88         89    3
# 18  0 - 5 years  Male     Pedestrians    0         29         29    0
# 19  0 - 5 years  Male  Pedal cyclists    0          1          1    0
# 20  0 - 5 years  Male  Motor cyclists    0          0          0    0
# 21  0 - 5 years  Male   All Car users    1         53         54    3
#
#    Unnamed: 7 Unnamed: 8 2015 Unnamed: 10 Unnamed: 11
# 17        121        124    1          97          98
# 18         47         47    0          28          28
# 19          1          1    0           3           3
# 20          0          0    0           0           0
# 21         70         73    1          63          64

# %%
# total injured killed not relevant as they are not in other dataframes

# %%
df5 = df5.drop(columns=['Unnamed: 5', 'Unnamed: 8', 'Unnamed: 11'])

# %%
df5.insert(3, 'CasualtyType', 'Injured')

# %%
df5.head()
# Out:
#             Age   Sex     Participant CasualtyType 2013 Unnamed: 4 2014  \
# 17  0 - 5 years  Male  All road users      Injured    1         88    3
# 18  0 - 5 years  Male     Pedestrians      Injured    0         29    0
# 19  0 - 5 years  Male  Pedal cyclists      Injured    0          1    0
# 20  0 - 5 years  Male  Motor cyclists      Injured    0          0    0
# 21  0 - 5 years  Male   All Car users      Injured    1         53    3
#
#    Unnamed: 7 2015 Unnamed: 10
# 17        121    1          97
# 18         47    0          28
# 19          1    0           3
# 20          0    0           0
# 21         70    1          63

# %%
# note values 'all road/car users' these are unique to this dataframe and must be removed

# %%
df5 = df5[df5.Participant != 'All road users']

# %%
df5 = df5[df5.Participant != 'All Car users']

# %%
#above values are not in same rows of other dataframes must be moved to merge

# %%
df5.shape
# Out:
# (145, 10)

# %%
df5.head()
# Out:
#             Age   Sex     Participant CasualtyType 2013 Unnamed: 4 2014  \
# 18  0 - 5 years  Male     Pedestrians      Injured    0         29    0
# 19  0 - 5 years  Male  Pedal cyclists      Injured    0          1    0
# 20  0 - 5 years  Male  Motor cyclists      Injured    0          0    0
# 22  0 - 5 years  Male     Car drivers      Injured    0          0    0
# 23  0 - 5 years  Male  Car passengers      Injured    1         53    3
#
#    Unnamed: 7 2015 Unnamed: 10
# 18         47    0          28
# 19          1    0           3
# 20          0    0           0
# 22          0    0           1
# 23         70    1          62

# %%
#after trying melting i felt the best way to join injured and killed columns was to create seperate dataframes and merge them

# %%
injured = df5.drop(columns=[2013, 2014, 2015])

# %%
killed = df5.drop(columns=['Unnamed: 4', 'Unnamed: 7', 'Unnamed: 10'])

# %%
injured = injured.rename(columns={'Unnamed: 4': 2013, 'Unnamed: 7': 2014, 'Unnamed: 10': 2015})

# %%
killed.CasualtyType[killed.CasualtyType == 'Injured'] = 'Killed'

# %%
killed.head()
# Out:
#             Age   Sex     Participant CasualtyType 2013 2014 2015
# 18  0 - 5 years  Male     Pedestrians       Killed    0    0    0
# 19  0 - 5 years  Male  Pedal cyclists       Killed    0    0    0
# 20  0 - 5 years  Male  Motor cyclists       Killed    0    0    0
# 22  0 - 5 years  Male     Car drivers       Killed    0    0    0
# 23  0 - 5 years  Male  Car passengers       Killed    1    3    1

# %%
killed.shape
# Out:
# (145, 7)

# %%
injured.shape
# Out:
# (145, 7)

# %%
trial = pd.concat([killed, injured])

# %%
trial.shape
# Out:
# (290, 7)

# %%
#check for duplicate values to see if thats the extra two rows

# %%
trial = trial.drop_duplicates()

# %%
trial.shape
# Out:
# (288, 7)

# %%
trial.head()
# Out:
#             Age   Sex     Participant CasualtyType 2013 2014 2015
# 18  0 - 5 years  Male     Pedestrians       Killed    0    0    0
# 19  0 - 5 years  Male  Pedal cyclists       Killed    0    0    0
# 20  0 - 5 years  Male  Motor cyclists       Killed    0    0    0
# 22  0 - 5 years  Male     Car drivers       Killed    0    0    0
# 23  0 - 5 years  Male  Car passengers       Killed    1    3    1

# %%
trial.reset_index(inplace=True)

# %%
trial.head()
# Out:
#    index          Age   Sex     Participant CasualtyType 2013 2014 2015
# 0     18  0 - 5 years  Male     Pedestrians       Killed    0    0    0
# 1     19  0 - 5 years  Male  Pedal cyclists       Killed    0    0    0
# 2     20  0 - 5 years  Male  Motor cyclists       Killed    0    0    0
# 3     22  0 - 5 years  Male     Car drivers       Killed    0    0    0
# 4     23  0 - 5 years  Male  Car passengers       Killed    1    3    1

# %%
trial.drop(columns=['index'])
# Out:
#                    Age     Sex       Participant CasualtyType 2013 2014 2015
# 0          0 - 5 years    Male       Pedestrians       Killed    0    0    0
# 1          0 - 5 years    Male    Pedal cyclists       Killed    0    0    0
# 2          0 - 5 years    Male    Motor cyclists       Killed    0    0    0
# 3          0 - 5 years    Male       Car drivers       Killed    0    0    0
# 4          0 - 5 years    Male    Car passengers       Killed    1    3    1
# 5          0 - 5 years    Male  Other road users       Killed    0    0    0
# 6          0 - 5 years  Female       Pedestrians       Killed    1    2    0
# 7          0 - 5 years  Female    Pedal cyclists       Killed    0    0    0
# 8          0 - 5 years  Female    Motor cyclists       Killed    0    0    0
# 9          0 - 5 years  Female       Car drivers       Killed    0    0    0
# 10         0 - 5 years  Female    Car passengers       Killed    1    0    1
# ...

# %%
finished = pd.merge(df1234, trial)

# %%
finished.shape
# Out:
# (288, 16)

# %%
finished.head()
# Out:
#            Age   Sex     Participant CasualtyType  2005  2006  2007  2008  \
# 0  0 - 5 years  Male     Pedestrians      Injured    36    32    28    54
# 1  0 - 5 years  Male     Pedestrians       Killed     3     1     0     1
# 2  0 - 5 years  Male  Pedal cyclists      Injured     0     0     2     0
# 3  0 - 5 years  Male  Pedal cyclists       Killed     0     0     0     0
# 4  0 - 5 years  Male  Motor cyclists      Injured     0     0     0     0
#
#    2009  2010  2011  2012  index 2013 2014 2015
# 0    35    41    39    40     18   29   47   28
# 1     3     3     0     0     18    0    0    0
# 2     2     5     3     1     19    1    1    3
# 3     0     0     1     0     19    0    0    0
# 4     0     0     0     0     20    0    0    0

# %%
finished = finished.drop(columns=['index'])

# %%
finished.head()
# Out:
#            Age   Sex     Participant CasualtyType  2005  2006  2007  2008  \
# 0  0 - 5 years  Male     Pedestrians      Injured    36    32    28    54
# 1  0 - 5 years  Male     Pedestrians       Killed     3     1     0     1
# 2  0 - 5 years  Male  Pedal cyclists      Injured     0     0     2     0
# 3  0 - 5 years  Male  Pedal cyclists       Killed     0     0     0     0
# 4  0 - 5 years  Male  Motor cyclists      Injured     0     0     0     0
#
#    2009  2010  2011  2012 2013 2014 2015
# 0    35    41    39    40   29   47   28
# 1     3     3     0     0    0    0    0
# 2     2     5     3     1    1    1    3
# 3     0     0     1     0    0    0    0
# 4     0     0     0     0    0    0    0

# %%
finished.shape
# Out:
# (288, 15)

# %%
finished[2013] = finished[2013].astype('int64')

# %%
finished[2014] = finished[2014].astype('int64')

# %%
finished[2015] = finished[2015].astype('int64')

# %%
finished.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288 entries, 0 to 287
# Data columns (total 15 columns):
# Age             288 non-null object
# Sex             288 non-null object
# Participant     288 non-null object
# CasualtyType    288 non-null object
# 2005            288 non-null int64
# 2006            288 non-null int64
# 2007            288 non-null int64
# 2008            288 non-null int64
# 2009            288 non-null int64
# 2010            288 non-null int64
# 2011            288 non-null int64
# 2012            288 non-null int64
# 2013            288 non-null int64
# 2014            288 non-null int64
# 2015            288 non-null int64
# dtypes: int64(11), object(4)
# memory usage: 36.0+ KB

# %%
finished.shape
# Out:
# (288, 15)

# %%
finished.to_csv('table.csv', index=False)
